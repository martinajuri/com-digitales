# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
numIter = np.arange(100,20000,200)
Pa =np.zeros(len(numIter))
k = 0
for veces in numIter:
    Na = 0
    dado = np.zeros(veces)
    for N in range(veces):
        dado[N] = random.randint(1,6)
        if dado[N] % 2 == 0:
            Na+=1 
    Pa[k]= Na/N
    k+=1

# %%
plt.plot(numIter,Pa)
plt.xlabel('Número de iteraciones')
plt.ylabel('Na/N')
plt.title('Cálculo de la probabilidad por frecuencia relativa')
plt.grid()
plt.show()

# %%
print("La ultima probabilidad calculada es de: ",Pa[-1])
# Out:
# La ultima probabilidad calculada es de:  0.5030906075682195

# %%
print("La probablidad teórica de : ", 1/2)
# Out:
# La probablidad teórica de :  0.5

# %%
plt.hist(dado,12)
plt.show()
