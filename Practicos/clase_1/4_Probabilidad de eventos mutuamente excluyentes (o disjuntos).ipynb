# %%
import random
import numpy as np
import matplotlib.pyplot as plt

numIter = np.arange(100,20000,200)
Pa =np.zeros(len(numIter))
k = 0
for veces in numIter:
    Na = 0
    dado1 = np.zeros(veces)
    dado2 = np.zeros(veces)
    for N in range(veces):
        dado1[N] = random.randint(1,6)
        dado2[N] = random.randint(1,6)
        if (dado1[N] + dado2[N])<5:
            Na+=1 
    Pa[k]= Na/N
    k+=1

plt.plot(numIter,Pa)
plt.xlabel('Número de iteraciones')
plt.ylabel('Na/N')
plt.title('Cálculo de la probabilidad por frecuencia relativa')
plt.grid()
plt.show()

# %%
print("La ultima probabilidad calculada es de: ",Pa[-1])
print("La probablidad teórica de : ", 1/6)
# Out:
# La ultima probabilidad calculada es de:  0.16362631288004423
# La probablidad teórica de :  0.16666666666666666

# %%
plt.figure()
plt.hist(dado1,12)
plt.title('Dado 1')
plt.show()

plt.figure()
plt.hist(dado2,12)
plt.title('Dado 2')
plt.show()
